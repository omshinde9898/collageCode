# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# Objective function (we want to minimize this)
def objective_function(x):
    return x[0]**2 + x[1]**2  # Simple paraboloid

# Generate a random antibody (solution)
def random_antibody(bounds):
    return np.random.uniform(bounds[0], bounds[1], 2)

# Mutate an antibody (small change)
def mutate(antibody, mutation_rate, bounds):
    mutation = antibody + np.random.normal(0, mutation_rate, size=2)
    return np.clip(mutation, bounds[0], bounds[1])

# Main Clonal Selection Algorithm with theoretical outputs
def clonal_selection(objective_function, bounds, n_population=20, n_generations=50, n_clones=5, mutation_rate=0.1):

    population = [random_antibody(bounds) for _ in range(n_population)]
    history = []

    print("=== Clonal Selection Algorithm Theoretical Output ===\n")

    for gen in range(n_generations):
        fitness = np.array([objective_function(p) for p in population])
        sorted_indices = np.argsort(fitness)
        population = [population[i] for i in sorted_indices]
        best = population[0]
        best_fitness = fitness[sorted_indices[0]]
        avg_fitness = np.mean(fitness)

        # Print theoretical output
        print(f"Generation {gen+1:02d}:")
        print(f"  ▶ Best Antibody: {best}")
        print(f"  ▶ Best Fitness : {best_fitness:.4f}")
        print(f"  ▶ Avg Fitness  : {avg_fitness:.4f}\n")

        history.append(population)

        # Clone and mutate
        new_population = []
        for i in range(n_population):
            for _ in range(n_clones):
                clone = mutate(population[i], mutation_rate, bounds)
                new_population.append(clone)

        new_fitness = np.array([objective_function(p) for p in new_population])
        best_indices = np.argsort(new_fitness)[:n_population]
        population = [new_population[i] for i in best_indices]

    return history

# Animation function
def animate_clonal_selection(history, bounds):
    fig, ax = plt.subplots()
    x = np.linspace(bounds[0], bounds[1], 100)
    y = np.linspace(bounds[0], bounds[1], 100)
    X, Y = np.meshgrid(x, y)
    Z = objective_function([X, Y])
    contour = ax.contourf(X, Y, Z, levels=50, cmap='viridis')
    scat = ax.scatter([], [], c='red', s=30)

    # Add color bar and labels
    cbar = fig.colorbar(contour, ax=ax)
    cbar.set_label("Objective Function Value")
    ax.set_xlabel("X1")
    ax.set_ylabel("X2")

    def update(frame):
        data = np.array(history[frame])
        scat.set_offsets(data)
        ax.set_title(f"Clonal Selection - Generation {frame + 1}")
        return scat,

    ani = animation.FuncAnimation(fig, update, frames=len(history), interval=300, blit=True)
    plt.show()

# Parameters
bounds = [-5, 5]
history = clonal_selection(objective_function, bounds, n_population=15, n_generations=50, n_clones=5, mutation_rate=0.2)
animate_clonal_selection(history, bounds)
# Out:
# === Clonal Selection Algorithm Theoretical Output ===
#
# Generation 01:
#   ▶ Best Antibody: [-1.25927804 -1.42008127]
#   ▶ Best Fitness : 3.6024
#   ▶ Avg Fitness  : 20.0625
#
# Generation 02:
#   ▶ Best Antibody: [-0.98222989 -1.3137426 ]
#   ▶ Best Fitness : 2.6907
#   ▶ Avg Fitness  : 7.3877
#
# Generation 03:
#   ▶ Best Antibody: [-0.73005459 -1.3816577 ]
#   ▶ Best Fitness : 2.4420
#   ▶ Avg Fitness  : 3.0927
#
# Generation 04:
#   ▶ Best Antibody: [-0.34210074 -0.78758289]
#   ▶ Best Fitness : 0.7373
#   ▶ Avg Fitness  : 2.0525
#
# Generation 05:
#   ▶ Best Antibody: [-0.38660462 -0.5098814 ]
#   ▶ Best Fitness : 0.4094
#   ▶ Avg Fitness  : 1.0400
#
# Generation 06:
#   ▶ Best Antibody: [-0.2616251  -0.32747709]
#   ▶ Best Fitness : 0.1757
#   ▶ Avg Fitness  : 0.3872
#
# Generation 07:
#   ▶ Best Antibody: [-0.1203262  -0.05457391]
#   ▶ Best Fitness : 0.0175
#   ▶ Avg Fitness  : 0.1350
#
# Generation 08:
#   ▶ Best Antibody: [-0.02134226 -0.04933466]
#   ▶ Best Fitness : 0.0029
#   ▶ Avg Fitness  : 0.0259
#
# Generation 09:
#   ▶ Best Antibody: [ 0.0042914 -0.0058138]
#   ▶ Best Fitness : 0.0001
#   ▶ Avg Fitness  : 0.0102
#
# Generation 10:
#   ▶ Best Antibody: [0.01010972 0.00323183]
#   ▶ Best Fitness : 0.0001
#   ▶ Avg Fitness  : 0.0098
#
# Generation 11:
#   ▶ Best Antibody: [-0.00692943  0.02545391]
#   ▶ Best Fitness : 0.0007
#   ▶ Avg Fitness  : 0.0073
#
# Generation 12:
#   ▶ Best Antibody: [-0.00092184 -0.0007995 ]
#   ▶ Best Fitness : 0.0000
#   ▶ Avg Fitness  : 0.0041
#
# Generation 13:
#   ▶ Best Antibody: [0.01005117 0.01219447]
#   ▶ Best Fitness : 0.0002
#   ▶ Avg Fitness  : 0.0122
#
# Generation 14:
#   ▶ Best Antibody: [0.04456421 0.01164017]
#   ▶ Best Fitness : 0.0021
#   ▶ Avg Fitness  : 0.0101
#
# Generation 15:
#   ▶ Best Antibody: [ 0.01366552 -0.02139832]
#   ▶ Best Fitness : 0.0006
#   ▶ Avg Fitness  : 0.0088
#
# Generation 16:
#   ▶ Best Antibody: [-0.03034205  0.00963712]
#   ▶ Best Fitness : 0.0010
#   ▶ Avg Fitness  : 0.0147
#
# Generation 17:
#   ▶ Best Antibody: [-0.00622357 -0.04794984]
#   ▶ Best Fitness : 0.0023
#   ▶ Avg Fitness  : 0.0107
#
# Generation 18:
#   ▶ Best Antibody: [ 0.01408806 -0.01964086]
#   ▶ Best Fitness : 0.0006
#   ▶ Avg Fitness  : 0.0124
#
# Generation 19:
#   ▶ Best Antibody: [ 0.03013918 -0.00532109]
#   ▶ Best Fitness : 0.0009
#   ▶ Avg Fitness  : 0.0129
#
# Generation 20:
#   ▶ Best Antibody: [-0.01054124  0.02259718]
#   ▶ Best Fitness : 0.0006
#   ▶ Avg Fitness  : 0.0125
#
# Generation 21:
#   ▶ Best Antibody: [ 0.0187965  -0.01871307]
#   ▶ Best Fitness : 0.0007
#   ▶ Avg Fitness  : 0.0121
#
# Generation 22:
#   ▶ Best Antibody: [0.04338977 0.00434183]
#   ▶ Best Fitness : 0.0019
#   ▶ Avg Fitness  : 0.0100
#
# Generation 23:
#   ▶ Best Antibody: [0.00691119 0.01884698]
#   ▶ Best Fitness : 0.0004
#   ▶ Avg Fitness  : 0.0042
#
# Generation 24:
#   ▶ Best Antibody: [0.04922166 0.01866699]
#   ▶ Best Fitness : 0.0028
#   ▶ Avg Fitness  : 0.0102
#
# Generation 25:
#   ▶ Best Antibody: [-0.03013484 -0.02138031]
#   ▶ Best Fitness : 0.0014
#   ▶ Avg Fitness  : 0.0087
#
# Generation 26:
#   ▶ Best Antibody: [-0.01795895 -0.03215401]
#   ▶ Best Fitness : 0.0014
#   ▶ Avg Fitness  : 0.0100
#
# Generation 27:
#   ▶ Best Antibody: [0.02323605 0.01098454]
#   ▶ Best Fitness : 0.0007
#   ▶ Avg Fitness  : 0.0079
#
# Generation 28:
#   ▶ Best Antibody: [0.01068238 0.01397492]
#   ▶ Best Fitness : 0.0003
#   ▶ Avg Fitness  : 0.0057
#
# Generation 29:
#   ▶ Best Antibody: [-0.00388566  0.01729536]
#   ▶ Best Fitness : 0.0003
#   ▶ Avg Fitness  : 0.0143
#
# Generation 30:
#   ▶ Best Antibody: [0.01478311 0.02050779]
#   ▶ Best Fitness : 0.0006
#   ▶ Avg Fitness  : 0.0068
#
# Generation 31:
#   ▶ Best Antibody: [ 0.0198554  -0.00301027]
#   ▶ Best Fitness : 0.0004
#   ▶ Avg Fitness  : 0.0088
#
# Generation 32:
#   ▶ Best Antibody: [-0.05422241  0.01646383]
#   ▶ Best Fitness : 0.0032
#   ▶ Avg Fitness  : 0.0147
#
# Generation 33:
#   ▶ Best Antibody: [ 0.00597056 -0.016819  ]
#   ▶ Best Fitness : 0.0003
#   ▶ Avg Fitness  : 0.0108
#
# Generation 34:
#   ▶ Best Antibody: [-0.0016789   0.02709658]
#   ▶ Best Fitness : 0.0007
#   ▶ Avg Fitness  : 0.0116
#
# Generation 35:
#   ▶ Best Antibody: [0.04107985 0.00341323]
#   ▶ Best Fitness : 0.0017
#   ▶ Avg Fitness  : 0.0069
#
# Generation 36:
#   ▶ Best Antibody: [-0.02317205 -0.00837574]
#   ▶ Best Fitness : 0.0006
#   ▶ Avg Fitness  : 0.0103
#
# Generation 37:
#   ▶ Best Antibody: [-0.01360195 -0.02358378]
#   ▶ Best Fitness : 0.0007
#   ▶ Avg Fitness  : 0.0078
#
# Generation 38:
#   ▶ Best Antibody: [0.02889949 0.02163793]
#   ▶ Best Fitness : 0.0013
#   ▶ Avg Fitness  : 0.0171
#
# Generation 39:
#   ▶ Best Antibody: [-0.01050317 -0.04386975]
#   ▶ Best Fitness : 0.0020
#   ▶ Avg Fitness  : 0.0147
#
# Generation 40:
#   ▶ Best Antibody: [-0.00220617  0.01898859]
#   ▶ Best Fitness : 0.0004
#   ▶ Avg Fitness  : 0.0107
#
# Generation 41:
#   ▶ Best Antibody: [-0.00023133 -0.00699865]
#   ▶ Best Fitness : 0.0000
#   ▶ Avg Fitness  : 0.0093
#
# Generation 42:
#   ▶ Best Antibody: [-0.01686929  0.02435513]
#   ▶ Best Fitness : 0.0009
#   ▶ Avg Fitness  : 0.0132
#
# Generation 43:
#   ▶ Best Antibody: [-0.01073959  0.01535209]
#   ▶ Best Fitness : 0.0004
#   ▶ Avg Fitness  : 0.0076
#
# Generation 44:
#   ▶ Best Antibody: [0.01501056 0.02929939]
#   ▶ Best Fitness : 0.0011
#   ▶ Avg Fitness  : 0.0093
#
# Generation 45:
#   ▶ Best Antibody: [ 0.01001751 -0.00490239]
#   ▶ Best Fitness : 0.0001
#   ▶ Avg Fitness  : 0.0100
#
# Generation 46:
#   ▶ Best Antibody: [ 0.00555984 -0.02549478]
#   ▶ Best Fitness : 0.0007
#   ▶ Avg Fitness  : 0.0073
#
# Generation 47:
#   ▶ Best Antibody: [-0.03556548  0.00619416]
#   ▶ Best Fitness : 0.0013
#   ▶ Avg Fitness  : 0.0111
#
# Generation 48:
#   ▶ Best Antibody: [ 0.00829207 -0.01320162]
#   ▶ Best Fitness : 0.0002
#   ▶ Avg Fitness  : 0.0104
#
# Generation 49:
#   ▶ Best Antibody: [0.01784156 0.02571968]
#   ▶ Best Fitness : 0.0010
#   ▶ Avg Fitness  : 0.0057
#
# Generation 50:
#   ▶ Best Antibody: [ 0.0427267  -0.03584811]
#   ▶ Best Fitness : 0.0031
#   ▶ Avg Fitness  : 0.0118
